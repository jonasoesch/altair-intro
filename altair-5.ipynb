# %% [markdown]
# #### A data exploration in Altair:
# ## 5. Building an overview
#
# Contact: jonas.oesch@nzz.ch

# %% [markdown]
# Import the necessary libraries and don't include the data in Vega-Lite specifications:

# %%
import pandas as pd
import altair as alt

alt.data_transformers.enable('data_server')
# Out:
# DataTransformerRegistry.enable('data_server')

# %% [markdown]
# Read the data, convert into correct types and preview:

# %%
data = pd.read_excel("Olympics.xlsx")
data.Year = pd.to_datetime(data.Year)
data.head(3)
# Out:
#         Year    City     Sport Discipline           Athlete Gender  \
# 0 1896-01-01  Athens  Aquatics   Swimming     HAJOS, Alfred    Men
# 1 1896-01-01  Athens  Aquatics   Swimming     HAJOS, Alfred    Men
# 2 1896-01-01  Athens  Aquatics   Swimming  HERSCHMANN, Otto    Men
#
#             Event   Medal  Country Code  ...  Durability  Endurance  \
# 0  100M Freestyle    Gold  Hungary  HUN  ...        4.63       9.25
# 1  100M Freestyle    Gold  Hungary  HUN  ...        3.25       4.13
# 2  100M Freestyle  Silver  Austria  AUT  ...        4.63       9.25
#
#   Flexibility  Hand-Eye Coordination  Nerve  Power  Rank  Speed  Strength  \
# 0         5.5                   2.88   2.63   4.63    36   5.50      5.25
# 1         5.5                   2.75   2.50   6.25    45   7.88      5.25
# 2         5.5                   2.88   2.63   4.63    36   5.50      5.25
#
#     Total
# 0  46.875
# 1  44.125
# 2  46.875
#
# [3 rows x 25 columns]

# %% [markdown]
# On to the question of: who wins medals. Medal count per country:

# %%
alt.Chart(data).mark_bar().encode(
    y="Country",
    x="count()",
)
# Out:
# alt.Chart(...)

# %% [markdown]
# That should be sorted …

# %%
c1 = alt.Chart(data).mark_bar().encode(
    y=alt.Y("Country", sort="-x"),
    x=alt.X("count()"),
)
c1
# Out:
# alt.Chart(...)

# %% [markdown]
# And distinguish by the type of medal …

# %%
c1.encode(
    color="Medal"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# And have a fitting color scheme in the right order …

# %%
medals = alt.Color(
    "Medal", 
    scale=alt.Scale(
        domain=["Gold", "Silver", "Bronze"], 
        range=["gold", "silver", "brown"]
    )
)

c2 = c1.encode(
    color=medals
)
c2
# Out:
# alt.Chart(...)

# %% [markdown]
# Remove all countries that have won less than 10 medals:

# %%
d2 = data.groupby("Country").Medal.count()
data['Medal_count'] = data.Country.map(d2)
data
# Out:
#             Year    City     Sport   Discipline                  Athlete  \
# 0     1896-01-01  Athens  Aquatics     Swimming            HAJOS, Alfred
# 1     1896-01-01  Athens  Aquatics     Swimming            HAJOS, Alfred
# 2     1896-01-01  Athens  Aquatics     Swimming         HERSCHMANN, Otto
# 3     1896-01-01  Athens  Aquatics     Swimming         HERSCHMANN, Otto
# 4     1896-01-01  Athens  Aquatics     Swimming        DRIVAS, Dimitrios
# ...          ...     ...       ...          ...                      ...
# 21479 2014-01-01   Sochi    Skiing  Ski Jumping          SHIMIZU, Reruhi
# 21480 2014-01-01   Sochi    Skiing  Ski Jumping           TAKEUCHI, Taku
# 21481 2014-01-01   Sochi    Skiing  Ski Jumping  IRASCHKO-STOLZ, Daniela
# 21482 2014-01-01   Sochi    Skiing  Ski Jumping           MATTEL, Coline
# 21483 2014-01-01   Sochi    Skiing  Ski Jumping             VOGT, Carina
#
#       Gender                       Event   Medal  Country Code  ...  \
# 0        Men              100M Freestyle    Gold  Hungary  HUN  ...
# 1        Men              100M Freestyle    Gold  Hungary  HUN  ...
# 2        Men              100M Freestyle  Silver  Austria  AUT  ...
# 3        Men              100M Freestyle  Silver  Austria  AUT  ...
# 4        Men  100M Freestyle For Sailors  Bronze   Greece  GRE  ...
# ...      ...                         ...     ...      ...  ...  ...
# 21479    Men                       Teams  Bronze    Japan  JPN  ...
# 21480    Men                       Teams  Bronze    Japan  JPN  ...
# 21481  Women              K90 Individual  Silver  Austria  AUT  ...
# 21482  Women              K90 Individual  Bronze   France  FRA  ...
# 21483  Women              K90 Individual    Gold  Germany  GER  ...
#
#        Endurance  Flexibility Hand-Eye Coordination  Nerve  Power  Rank  \
# 0           9.25          5.5                  2.88   2.63   4.63    36
# 1           4.13          5.5                  2.75   2.50   6.25    45
# 2           9.25          5.5                  2.88   2.63   4.63    36
# 3           4.13          5.5                  2.75   2.50   6.25    45
# 4           9.25          5.5                  2.88   2.63   4.63    36
# ...          ...          ...                   ...    ...    ...   ...
# 21479       3.50          5.0                  4.38   9.00   5.75    29
# 21480       3.50          5.0                  4.38   9.00   5.75    29
# 21481       3.50          5.0                  4.38   9.00   5.75    29
# 21482       3.50          5.0                  4.38   9.00   5.75    29
# 21483       3.50          5.0                  4.38   9.00   5.75    29
#
#        Speed  Strength   Total  Medal_count
# 0       5.50      5.25  46.875          731
# 1       7.88      5.25  44.125          731
# 2       5.50      5.25  46.875          211
# 3       7.88      5.25  44.125          211
# 4       5.50      5.25  46.875           50
# ...      ...       ...     ...          ...
# 21479   4.63      4.50  48.875          630
# 21480   4.63      4.50  48.875          630
# 21481   4.63      4.50  48.875          211
# 21482   4.63      4.50  48.875         1118
# 21483   4.63      4.50  48.875         1164
#
# [21484 rows x 26 columns]

# %%
c3 = alt.Chart(data[data.Medal_count > 10]).mark_bar().encode(
    y=alt.Y("Country", sort="-x"),
    x=alt.X("count()", stack="normalize"),
    color=medals
)
c3
# Out:
# alt.Chart(...)

# %%
c3 | c1
# Out:
# alt.HConcatChart(...)
